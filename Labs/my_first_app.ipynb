# %%
from datetime import datetime

name = "Oleh"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Oleh start programming at 2025-11-30 18:31:24.006542. Lviv is the best city!

# %% [markdown]
# ## Моя перша програма
# Це простий Python-скрипт, який використовує модуль datetime для виведення поточного часу та персоналізованого повідомлення.
