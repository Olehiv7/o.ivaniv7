# %% [markdown]
# 📝 Звіт до лабораторної роботи №2
# Тема: Основи програмування на Python: Базові конструкції
#
# Мета роботи
#
# Навчитись застосовувати основні конструкції мови Python, виконати всі приклади та з використанням AI створити власні приклади, які демонструють особливості кодових конструкцій Pyhton.
#
# Виконання роботи
# 1. Основні типи даних та змінні
#
# Познайомились з основними типами даних: рядок (str), ціле число (int), число з рухомою комою (float), список (list), словник (dict), кортеж (tuple) та множина (set).
#
# Вставлений код:

# %%
a = "змінна з текстом"
b = 1
b1 = 1.1
c = ["a", 1, 1.25, "Слово", a] # List
d = {"a": "Слово", "b": 1, "текст_змінної_a": b} # Dict
e = ("a", a) # Tuple
f = {"ss", str(a) + str(b)} # Set

print(f"Змінна 'a' (str): {a}, Тип: {type(a)}")
print(f"Змінна 'c' (list): {c}, Тип: {type(c)}")
print(f"Змінна 'd' (dict): {d}, Тип: {type(d)}")
print(f"Змінна 'e' (tuple): {e}, Тип: {type(e)}")
print(f"Змінна 'f' (set): {f}, Тип: {type(f)}")
# Out:
# Змінна 'a' (str): змінна з текстом, Тип: <class 'str'>
# Змінна 'c' (list): ['a', 1, 1.25, 'Слово', 'змінна з текстом'], Тип: <class 'list'>
# Змінна 'd' (dict): {'a': 'Слово', 'b': 1, 'текст_змінної_a': 1}, Тип: <class 'dict'>
# Змінна 'e' (tuple): ('a', 'змінна з текстом'), Тип: <class 'tuple'>
# Змінна 'f' (set): {'ss', 'змінна з текстом1'}, Тип: <class 'set'>

# %% [markdown]
# 2. Вбудовані константи та зарезервовані слова

# %%
print("Перша константа (Логічна Істина):", True)
print("Друга константа (Відсутність значення):", None)
print("-" * 30)
# help("keywords") # Команда виведена у термінал
# Out:
# Перша константа (Логічна Істина): True
# Друга константа (Відсутність значення): None
# ------------------------------

# %% [markdown]
# 3. Результат роботи вбудованих функцій

# %%
num = 3.14159
print(f"Абсолютне значення -12.5 є рівним {abs(-12.5)}")
print(f"Довжина списку c: {len(c)}")
print(f"Число {num} округлене до 2 знаків: {round(num, 2)}")
# Out:
# Абсолютне значення -12.5 є рівним 12.5
# Довжина списку c: 5
# Число 3.14159 округлене до 2 знаків: 3.14

# %% [markdown]
# 4. Цикли та Розгалуження

# %%
# Цикл FOR
letters = ["a", "b", "c"]
for i in range(len(letters)):
    print(f"На позиції {i} знаходиться буква {letters[i]}")
else:
    print("Цикл завершено.")

# Розгалуження if/elif/else
from random import randint
temperature = randint(-5, 10)
print(f"\nПоточна температура: {temperature}°C")
if temperature < 0:
    print("Дуже холодно!")
elif temperature >= 0 and temperature < 5:
    print("Прохолодно, одягніть куртку.")
else:
    print("Тепло, можна гуляти!")

# %% [markdown]
# Конструкція try/except/finally та Контекст-менеджер with

# %%
A = 0
try:
    result = 10 / A
except ZeroDivisionError as e:
    print("Невже це помилка > ZeroDivisionError:", e)
finally:
    print("Блок 'finally' завжди виконується.")
# Out:
# Невже це помилка > ZeroDivisionError: division by zero
# Блок 'finally' завжди виконується.

# %%
try:
    with open("README.md", "r") as f:
        print(f"Файл відкритий? {f.closed == False}")
        # (Читання файлу)
except FileNotFoundError:
    print("Помилка: Файл README.md не знайдено.")
# Out:
# Файл відкритий? True

# %% [markdown]
# Python Lambdas

# %%
this_is_lambda = lambda first, age: f'Створив: {first}, Мені {age} років'
print("Це її виклик:", this_is_lambda('Олег', 20))

students = [('Олег', 20), ('Анна', 22), ('Іван', 19)]
sorted_students = sorted(students, key=lambda student: student[1])
print(f"Студенти за віком: {sorted_students}")
# Out:
# Це її виклик: Створив: Олег, Мені 20 років
# Студенти за віком: [('Іван', 19), ('Олег', 20), ('Анна', 22)]

# %% [markdown]
# Висновок
# Питання	Відповідь
# ❓ Що зроблено в роботі?	Виконано всі практичні приклади основних конструкцій мови Python: типи даних, константи, вбудовані функції, цикли, розгалуження, обробка винятків (try/except), контекстні менеджери (with) та лямбда-функції. Створено та оформлено звіт.
# ❓ Чи досягнуто мети роботи?	Так. Мета роботи досягнута. Вдалося застосувати основні конструкції мови Python та продемонструвати їх використання.
# ❓ Які нові знання отримано?	Отримано знання про роботу з множинами (set), кортежами (tuple), практичне застосування лямбда-функцій, а також коректну обробку помилок за допомогою try/except.
# ❓ Чи вдалось відповісти на всі питання, задані в ході роботи?	Так. Всі навчальні приклади були виконані, а помилки, що виникали, успішно виправлені та проаналізовані.
# ❓ Чи вдалося виконати всі завдання?	Так. Усі завдання щодо кодових конструкцій, окрім індивідуального завдання з AI та оформлення звіту були виконані.
# ❓ Чи виникли складності у виконанні завдання?	Так. Виникли невеликі синтаксичні помилки при визначенні змінних (SyntaxError, NameError), які були оперативно виправлені. Також виникали повідомлення від Git, що вимагали ігнорування під час активної роботи над кодом.
# ❓ Чи подобається такий формат здачі роботи (Feedback)?	Так, інтерактивний формат Jupyter Notebook ідеально підходить для вивчення основ програмування, оскільки дозволяє миттєво бачити результати кожної комірки.
# ❓ Побажання для покращення (Suggestions)?	Вважаю, що було б корисно включати більше практичних прикладів використання лямбда-функцій з функціями map та filter для кращого розуміння.
